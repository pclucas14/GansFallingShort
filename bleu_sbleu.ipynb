# %% [markdown]
# ## NEWS DATA

# %%
import matplotlib.pyplot as plt
import plotly.plotly as py

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(font_scale=2)  # Make sure everything is readable.
sns.set_style("whitegrid")

# %%
seqgan  = [-0.09,  0.27]
maligan = [-0.08,  0.25]
rankgan = [-0.09,  0.30]
leakgan = [-0.27,  0.51]
cot     = [-0.20,  0.18] 
train   = [-0.23,  0.24]
mle_rep = [-0.13,  0.17]

eps = 0.005
size=17
fig = plt.figure()
ax = fig.add_subplot(111)

x = [-0.19, -0.21, -0.22, -0.23, -0.25, -0.26, -0.27, -0.28, -0.29, -0.30, -0.32, -0.33, -0.34, -0.35, -0.36 ]
y = [0.21, 0.23, 0.25, 0.27, 0.29, 0.31, 0.33, 0.35, 0.37, 0.39, 0.41, 0.43, 0.45, 0.46, 0.48 ]

ax.plot(x,y,'r', alpha=0.0)
# ax.annotate('MLE', xy=(-0.27, 0.33), xytext=(-0.30, 0.32),size=size)

# ax.plot(mle_rep[0],mle_rep[1], 'o')
# ax.annotate('MLE (reported)', xy=(mle_rep[0],mle_rep[1]), xytext=(mle_rep[0]-0.085,mle_rep[1]-eps),size=size)
ax.plot(seqgan[0],seqgan[1], 'o')
ax.annotate('SeqGAN', xy=(seqgan[0],seqgan[1]),    xytext=(seqgan[0]-0.05,seqgan[1]-eps),size=size)
ax.plot(maligan[0],maligan[1], 'o')
ax.annotate('MaliGAN', xy=(maligan[0],maligan[1]), xytext=(maligan[0]-0.05,maligan[1]-3*eps),size=size)
ax.plot(rankgan[0],rankgan[1], 'o')
ax.annotate('RankGAN', xy=(rankgan[0],rankgan[1]), xytext=(rankgan[0]-0.055,rankgan[1]),size=size)
ax.plot(leakgan[0],leakgan[1], 'o',color='c')
ax.annotate('LeakGAN', xy=(leakgan[0],leakgan[1]), xytext=(leakgan[0]+eps,leakgan[1]-eps),size=size)
ax.plot(train[0],train[1], 'o',color='k')
ax.annotate('train data', xy=(train[0],train[1]),  xytext=(train[0]-0.055,train[1]-0.005),size=size)

ax.set_xlabel('-BLEU5')
ax.set_ylabel('SBLEU5')
plt.savefig('figs/news_bleu_sbleu_no_mle.png')
plt.show()

# %%
seqgan  = [-0.09,  0.27]
maligan = [-0.08,  0.25]
rankgan = [-0.09,  0.30]
leakgan = [-0.27,  0.51]
cot     = [-0.20,  0.18] 
train   = [-0.23,  0.24]
mle_rep = [-0.13,  0.17]

eps = 0.005
size=17
fig = plt.figure()
ax = fig.add_subplot(111)

x = [-0.19, -0.21, -0.22, -0.23, -0.25, -0.26, -0.27, -0.28, -0.29, -0.30, -0.32, -0.33, -0.34, -0.35, -0.36 ]
y = [0.21, 0.23, 0.25, 0.27, 0.29, 0.31, 0.33, 0.35, 0.37, 0.39, 0.41, 0.43, 0.45, 0.46, 0.48 ]

ax.plot(x,y,'r', alpha=1.0)
ax.annotate('MLE', xy=(-0.27, 0.33), xytext=(-0.30, 0.32),size=size)

# ax.plot(mle_rep[0],mle_rep[1], 'o')
# ax.annotate('MLE (reported)', xy=(mle_rep[0],mle_rep[1]), xytext=(mle_rep[0]-0.085,mle_rep[1]-eps),size=size)
ax.plot(seqgan[0],seqgan[1], 'o')
ax.annotate('SeqGAN', xy=(seqgan[0],seqgan[1]),    xytext=(seqgan[0]-0.05,seqgan[1]-eps),size=size)
ax.plot(maligan[0],maligan[1], 'o')
ax.annotate('MaliGAN', xy=(maligan[0],maligan[1]), xytext=(maligan[0]-0.05,maligan[1]-3*eps),size=size)
ax.plot(rankgan[0],rankgan[1], 'o',color='m')
ax.annotate('RankGAN', xy=(rankgan[0],rankgan[1]), xytext=(rankgan[0]-0.055,rankgan[1]),size=size)
ax.plot(leakgan[0],leakgan[1], 'o',color='c')
ax.annotate('LeakGAN', xy=(leakgan[0],leakgan[1]), xytext=(leakgan[0]+eps,leakgan[1]-eps),size=size)
ax.plot(train[0],train[1], 'o',color='k')
ax.annotate('train data', xy=(train[0],train[1]),  xytext=(train[0]-0.055,train[1]-0.005),size=size)

ax.set_xlabel('-BLEU5')
ax.set_ylabel('SBLEU5')
plt.savefig('figs/news_bleu_sbleu.png')
plt.show()

# %% [markdown]
# ## COCO DATA

# %%
seqgan  = [-0.18,  0.49]
maligan = [-0.16,  0.44]
rankgan = [-0.16,  0.62]
leakgan = [-0.21,  0.51]
# cot     = [-0.21,  0.18] 
textgan = [-0.21,  0.75]
train   = [-0.19,  0.42]
# mle_rep = [-0.13,  0.17]


eps = 0.001
size=17
fig = plt.figure()
ax = fig.add_subplot(111)

x = [-0.21]
y = [0.38 ]

ax.plot(x,y,'o', color='r')
ax.annotate('MLE', xy=(x[0],y[0]), xytext=(x[0]+eps,y[0]+eps),size=size)


ax.plot(seqgan[0],seqgan[1], 'o')
ax.annotate('SeqGAN', xy=(seqgan[0],seqgan[1]),    xytext=(seqgan[0]+eps,seqgan[1]-eps),size=size)
ax.plot(maligan[0],maligan[1], 'o')
ax.annotate('MaliGAN', xy=(maligan[0],maligan[1]), xytext=(maligan[0]-9*eps,maligan[1]-eps),size=size)
ax.plot(rankgan[0],rankgan[1], 'o',color='m')
ax.annotate('RankGAN', xy=(rankgan[0],rankgan[1]), xytext=(rankgan[0]-10*eps,rankgan[1]-eps),size=size)
ax.plot(leakgan[0],leakgan[1], 'o',color='c')
ax.annotate('LeakGAN', xy=(leakgan[0],leakgan[1]), xytext=(leakgan[0]+eps,leakgan[1]-eps),size=size)
ax.plot(train[0],train[1], 'o',color='k')
ax.annotate('train data', xy=(train[0],train[1]),  xytext=(train[0]-10*eps,train[1]-eps),size=size)

ax.set_xlabel('-BLEU5')
ax.set_ylabel('SBLEU5')
plt.savefig('figs/coco_bleu_sbleu.png')
plt.show()
